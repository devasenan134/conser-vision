# %%
import numpy as np
import pandas as pd
import cv2
from scipy import ndimage
from pathlib import Path
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
root_path = "D:\\Course\\DrivenData Project\\Dataset"
train_features_path = "train_features.csv"
train_labels_path = "train_features.csv"

# %%
cd D:\Course\DrivenData Project\Dataset
# Out:
# D:\Course\DrivenData Project\Dataset

# %%
train_features = pd.read_csv(train_features_path)
train_features.head()
# Out:
#          id                     filepath   site
# 0  ZJ000000  train_features/ZJ000000.jpg  S0120
# 1  ZJ000001  train_features/ZJ000001.jpg  S0069
# 2  ZJ000002  train_features/ZJ000002.jpg  S0009
# 3  ZJ000003  train_features/ZJ000003.jpg  S0008
# 4  ZJ000004  train_features/ZJ000004.jpg  S0036

# %%
# train_x = []

# for image in train_features.iloc[:, 1]:
#     img=cv2.imread(image)
#     img = cv2.resize(img, (335, 335))
#     train_x.append(img)

# %%
for image_file in train_features['filepath']:
    img = cv2.imread(image_file)
    img = cv2.resize(img,(335,335))

    dst = root_path +"\\"+ image_file
    cv2.imwrite(dst, img)

# %%
imgex=cv2.imread(train_features['filepath'].loc[0])
imgex.shape
# Out:
# (335, 335, 3)

# %%
image=imread(train_features['filepath'].loc[2],0)
plt.imshow(image)
plt.show()

# %%
image=cv2.imread(train_features['filepath'].loc[8],0)
# image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image)
plt.show()
np.array(image)
# Out:
# array([[127, 102,  78, ..., 153, 162, 159],
#        [106,  92,  88, ..., 151, 160, 164],
#        [ 89,  84,  89, ..., 160, 158, 159],
#        ...,
#        [143, 115, 120, ..., 254, 199, 245],
#        [139, 123, 129, ..., 241, 228, 243],
#        [137, 122, 126, ..., 248, 252, 243]], dtype=uint8)

# %%
image2=ndimage.gaussian_filter(image,sigma=0.3)
plt.imshow(image2)
plt.show()

# %%
def hist(img):
  img_to_yuv = cv2.cvtColor(img,cv2.COLOR_BGR2YUV)
  img_to_yuv[:,:,0] = cv2.equalizeHist(img_to_yuv[:,:,0])
  hist_equalization_result = cv2.cvtColor(img_to_yuv, cv2.COLOR_YUV2BGR)
  return hist_equalization_result

image1=hist(image)
plt.imshow(image1)
plt.show()

# %%
image3=hist(image2)
plt.imshow(image3)
plt.show()

# %%
# image1 = cv2.warpAffine(image, np.float32([[1, 0, 84], [0, 1, 56]]), (image.shape[0], image.shape[1]),borderMode=cv2.BORDER_CONSTANT,borderValue=(144, 159, 162))
# # image3 = cv2.warpAffine(image, np.float32([[1, 0, 84], [0, 1, 56]]), (image.shape[0], image.shape[1]),borderMode=cv2.BORDER_CONSTANT,borderValue=(144, 159, 162))
# plt.imshow(image1)
# plt.show()
